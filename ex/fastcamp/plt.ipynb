# %%
import matplotlib.pyplot as plt

# %%
#문제 x가 123, y가 456인 그래프를 그리시오
x = [1,2,3]
y = [4,5,6]
plt.figure()
plt.plot(x,y)

# %%
#plt.plot(x,y,linewidth =10, color = 'red')
#plt.plot(x,y,marker = 'o', markersize = 10)#데이터 위치 
#plt.plot(x,y, linestyle=':')
plt.plot(x,y, 'o')
plt.title('title', fontsize = 20)#타이틀 만들기
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)#뒤에 그리드를 넣어줌
plt.grid(True, axis='x')#aixs설정도 가능

# %%
plt.plot(x,y)
#plt.xlim([1,2])
#plt.ylim([4,5])#x,y최소,최대값 설정
plt.axis([1,2,4,5])#axis를 사용해서도 가능([x_min,x_max,y_min,y_max])
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 25)#글자 크기 변경
# Out:
# (array([4. , 4.2, 4.4, 4.6, 4.8, 5. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(x,y)
plt.text(2,5,'test', fontsize = 20)#텍스트 삽입도 가능
# Out:
# Text(2, 5, 'test')

# %%
#한글폰트 사용하기
'''
# %pip install matplotlib -U
# %sudo apt-get install -y fonts-nanum 
# %sudo fc-cache -fv 
# %rm ~/.cache/matplotlib -rf
'''
plt.plot(x,y)
plt.title('한글')
# Out:
# Text(0.5, 1.0, '한글')
# c:\ProgramData\Miniconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Miniconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.rcParams['font.family'] = ['NanumGothic', 'sans-serif']
plt.rcParams['axes.unicode_minus'] = False

x=[1,2,3]
plt.plot(x)
plt.title('차트명 한글')
# Out:
# Text(0.5, 1.0, '차트명 한글')

# %%
#여러 데이터를 한 차트에 그리기
#문제 data1(x:1,2,3, y:1,2,3)과 data2(x:1,2,3, y:1,4,7)을 그래프로 출력하시오
x1=[1,2,3]
y1=[1,2,3]
x2=[1,2,3]
y2=[1,4,7]
'''
plt.plot(x1,y1, color='blue')
plt.plot(x2,y2, color = 'red')
'''
#또는
plt.plot(x1,y1,'b', x2,y2,'r')
# Out:
# [<matplotlib.lines.Line2D at 0x20ea908d6a0>,
#  <matplotlib.lines.Line2D at 0x20ea908d5e0>]

# %%
#범례 추가하기
x1=[1,2,3]
y1=[1,2,3]
x2=[1,2,3]
y2=[1,4,7]
'''
plt.plot(x1,y1, color='blue', label = 'data1')
plt.plot(x2,y2, color = 'red', label ='data2')
plt.legend()#범례 추가

'''
#또는
plt.plot(x1,y1, color='blue')
plt.plot(x2,y2, color = 'red')

plt.legend(('data1', 'data2'), loc='upper right')#범례 위치도 추가

# %%
#subplot / subplots 를 이용한 여러개의 차트 그리기
x1=[1,2,3]
y1=[1,2,3]
x2=[1,2,3]
y2=[1,100,200]

#subplot을 이용한 해결
#subplot(행의 수, 열의 수, 해당 그래프가 그려질 위치)
plt.subplot(1,2,1)
plt.plot(x1,x2)
plt.title('data1')

plt.subplot(1,2,2)
plt.plot(x2,y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %%
#transpose
x1=[1,2,3]
y1=[1,2,3]
x2=[1,2,3]
y2=[1,100,200]

plt.subplot(2,1,1)
plt.plot(x1,x2)
plt.title('data1')

plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %%
#tight_layout을 이용하면 레이아웃이 자동으로 설정됨
